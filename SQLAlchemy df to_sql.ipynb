# %%
import pyodbc
import sqlalchemy as sqa
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = sqa.create_engine("mysql+mysqlconnector://root:abc123@127.0.0.1:3306/online_order")

# %%
df=pd.read_csv('6.June_data.csv')
df
# Out:
#        Unnamed: 0  Order ID  Consumer ID Product Name                Category  \
# 0               0    192998       142007   Product 71         Office Supplies
# 1               1    192999       186979   Product 80         Office Supplies
# 2               2    193000       118692   Product 83            Toys & Games
# 3               3    193001       191455  Product 100             Electronics
# 4               4    193002       139529   Product 47  Grocery & Gourmet Food
# ...           ...       ...          ...          ...                     ...
# 17434       17434    210432       171833   Product 45  Grocery & Gourmet Food
# 17435       17435    210433       178336   Product 34  Grocery & Gourmet Food
# 17436       17436    210434       108017    Product 1           Home & Garden
# 17437       17437    210435       112508   Product 80         Office Supplies
# 17438       17438    210436       168117   Product 35  Grocery & Gourmet Food
#
# ...

# %%
df.to_sql(name='master_data',con=engine,if_exists='replace',index=False)
